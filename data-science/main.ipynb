# %%
import pandas as pd;
import numpy as np;
import matplotlib.pyplot as plt;

traffic_data = pd.read_csv('./dataset_flujo_vehicular.csv');
filter_columns = traffic_data[['CANTIDAD', 'LATITUD', 'LONGITUD']];

#Comprobar que no haya datos vacios en mi dataset
print(filter_columns.info());
filter_columns.describe();
print(filter_columns.isnull().count())

cantidad_total = filter_columns.groupby(['LATITUD', 'LONGITUD']).agg('sum');

cantidad_total.to_csv("traffic_data.csv");

#MEJORAR SI HAY TIEMPO
y_labels = np.empty((1,8), dtype=str);
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 189814 entries, 0 to 189813
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   CANTIDAD  189814 non-null  int64
#  1   LATITUD   186412 non-null  float64
#  2   LONGITUD  186412 non-null  float64
# dtypes: float64(2), int64(1)
# memory usage: 4.3 MB
# None
# CANTIDAD    189814
# LATITUD     189814
# LONGITUD    189814
# dtype: int64
#                                 H_Fecha  Hora  AutNombre DispNombre  \
# 1/1/2023 0 AU 4  Lugones  RD165 Dorrego   4.0       74.0          A
#          1 AU 4  Lugones  RD165 Dorrego   4.0       74.0          A
#          2 AU 4  Lugones  RD165 Dorrego   4.0       74.0          A
#          3 AU 4  Lugones  RD165 Dorrego   4.0       74.0          A
#          4 AU 4  Lugones  RD165 Dorrego   4.0       74.0          A
#          5 AU 4  Lugones  RD165 Dorrego   4.0       74.0          A
#          6 AU 4  Lugones  RD165 Dorrego   4.0       74.0          A
#          7 AU 4  Lugones  RD165 Dorrego   4.0       74.0          A
#          8 AU 4  Lugones  RD165 Dorrego   4.0       74.0          A
#          9 AU 4  Lugones  RD165 Dorrego   4.0       74.0          A
#
#                           DispUbicacion  SeccionSentido   Lat      Lng  \
# 1/1/2023 0 AU 4  Lugones          -34.0         56336.0 -58.0  41529.0
#          1 AU 4  Lugones          -34.0         56336.0 -58.0  41529.0
#          2 AU 4  Lugones          -34.0         56336.0 -58.0  41529.0
#          3 AU 4  Lugones          -34.0         56336.0 -58.0  41529.0
#          4 AU 4  Lugones          -34.0         56336.0 -58.0  41529.0
#          5 AU 4  Lugones          -34.0         56336.0 -58.0  41529.0
#          6 AU 4  Lugones          -34.0         56336.0 -58.0  41529.0
#          7 AU 4  Lugones          -34.0         56336.0 -58.0  41529.0
#          8 AU 4  Lugones          -34.0         56336.0 -58.0  41529.0
#          9 AU 4  Lugones          -34.0         56336.0 -58.0  41529.0
#
#                           Cantidad
# 1/1/2023 0 AU 4  Lugones     887.0
#          1 AU 4  Lugones    3443.0
#          2 AU 4  Lugones    4383.0
#          3 AU 4  Lugones    2528.0
#          4 AU 4  Lugones    1135.0
#          5 AU 4  Lugones    1158.0
#          6 AU 4  Lugones    1147.0
#          7 AU 4  Lugones    1033.0
#          8 AU 4  Lugones     834.0
#          9 AU 4  Lugones     829.0
#                            AutNombre   Lat      Lng  Cantidad
# 1/1/2023 0  AU 4  Lugones       74.0 -58.0  41529.0     887.0
#          1  AU 4  Lugones       74.0 -58.0  41529.0    3443.0
#          2  AU 4  Lugones       74.0 -58.0  41529.0    4383.0
#          3  AU 4  Lugones       74.0 -58.0  41529.0    2528.0
#          4  AU 4  Lugones       74.0 -58.0  41529.0    1135.0
#          5  AU 4  Lugones       74.0 -58.0  41529.0    1158.0
#          6  AU 4  Lugones       74.0 -58.0  41529.0    1147.0
#          7  AU 4  Lugones       74.0 -58.0  41529.0    1033.0
#          8  AU 4  Lugones       74.0 -58.0  41529.0     834.0
#          9  AU 4  Lugones       74.0 -58.0  41529.0     829.0
#          10 AU 4  Lugones       74.0 -58.0  41529.0    1096.0
#          11 AU 4  Lugones       74.0 -58.0  41529.0    1565.0
#          12 AU 4  Lugones       74.0 -58.0  41529.0    2272.0
#          13 AU 4  Lugones       74.0 -58.0  41529.0    2271.0
#          14 AU 4  Lugones       74.0 -58.0  41529.0    2040.0
#          15 AU 4  Lugones       74.0 -58.0  41529.0    2499.0
#          16 AU 4  Lugones       74.0 -58.0  41529.0    3294.0
#          17 AU 4  Lugones       74.0 -58.0  41529.0    3580.0
#          18 AU 4  Lugones       74.0 -58.0  41529.0    3846.0
#          19 AU 4  Lugones       74.0 -58.0  41529.0    3963.0
